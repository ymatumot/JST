# %% [markdown]
# # 課題１：HR図

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
df=pd.read_csv('HP.csv')
#df=df[(df['RA'] > 60) & (df['RA'] < 70) & (df['DE'] > 10) & (df['DE'] < 20)]
#df['Vmag']=df['Vmag']+5*np.log10(df['Plx'])-10
df.plot.scatter(x='B-V',y='Vmag',ylim=[20,-5])
#Mvp=11.3-5.0*np.log10(1.3)+5.0
#plt.scatter(1.82,Mvp,marker='x',c='red')
plt.show()
