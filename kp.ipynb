# %% [markdown]
# # 課題２：ハビタブル惑星（ケプラー衛星）

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
df=pd.read_csv('KP.csv',comment='#')
df.plot.scatter(x='pl_orbper',y='pl_bmassj',xlim=[1,1000],ylim=[0,10])
#                logx=True, logy=True)
#df['pl_eqt']=0.05*np.sqrt(df['st_rad']/df['pl_orbsmax'])*df['st_teff']
#df=df[(df['pl_eqt'] > 273) & (df['pl_eqt'] < 373)]
#df.plot.scatter(x='pl_orbsmax',y='st_teff',xlim=[0,1.0],ylim=[0,8000])
#plt.scatter(x=0.049,y=3042,s=100,marker='+',c='red')
plt.xlabel("Orbital Period [days]")
plt.ylabel("Planet Mass/M_J")
plt.show()
